# %%
import pandas as pd

# %%
df = pd.read_csv('Airline_Delay_Cause.csv')
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023      8      9E  Endeavor Air Inc.     ABE
# 1  2023      8      9E  Endeavor Air Inc.     ABY
# 2  2023      8      9E  Endeavor Air Inc.     AEX
# 3  2023      8      9E  Endeavor Air Inc.     AGS
# 4  2023      8      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0       13.0
# 1             Albany, GA: Southwest Georgia Regional         62.0       10.0
# 2           Alexandria, LA: Alexandria International         62.0       10.0
# 3        Augusta, GA: Augusta Regional at Bush Field         66.0       12.0
# 4                   Albany, NY: Albany International         92.0       22.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.25        1.60  ...          0.0              5.99            2.0
# ...

# %%
df.shape
# Out:
# (171666, 21)

# %%
df.isnull().sum()/len(df)
# Out:
# year                   0.000000
# month                  0.000000
# carrier                0.000000
# carrier_name           0.000000
# airport                0.000000
# airport_name           0.000000
# arr_flights            0.001398
# arr_del15              0.002581
# carrier_ct             0.001398
# weather_ct             0.001398
# nas_ct                 0.001398
# security_ct            0.001398
# late_aircraft_ct       0.001398
# arr_cancelled          0.001398
# arr_diverted           0.001398
# arr_delay              0.001398
# carrier_delay          0.001398
# weather_delay          0.001398
# nas_delay              0.001398
# security_delay         0.001398
# late_aircraft_delay    0.001398
# dtype: float64

# %%
df.dropna()
df.shape
# Out:
# (171666, 21)

# %%
X = df.select_dtypes(include='number').columns
df[X].skew(axis=0,skipna=True)
# Out:
# year                   -0.254111
# month                  -0.003061
# arr_flights             8.435474
# arr_del15               7.253163
# carrier_ct              6.995679
# weather_ct             10.789152
# nas_ct                  8.074756
# security_ct            15.119111
# late_aircraft_ct        7.835102
# arr_cancelled          33.552191
# arr_diverted           14.548013
# arr_delay               9.211512
# carrier_delay          10.820572
# weather_delay          11.826292
# nas_delay               9.980895
# security_delay         25.004564
# late_aircraft_delay     9.683049
# dtype: float64

# %%
df[X].hist(bins=30,figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'month'}>,
#         <Axes: title={'center': 'arr_flights'}>,
#         <Axes: title={'center': 'arr_del15'}>],
#        [<Axes: title={'center': 'carrier_ct'}>,
#         <Axes: title={'center': 'weather_ct'}>,
#         <Axes: title={'center': 'nas_ct'}>,
#         <Axes: title={'center': 'security_ct'}>],
#        [<Axes: title={'center': 'late_aircraft_ct'}>,
#         <Axes: title={'center': 'arr_cancelled'}>,
#         <Axes: title={'center': 'arr_diverted'}>,
#         <Axes: title={'center': 'arr_delay'}>],
#        [<Axes: title={'center': 'carrier_delay'}>,
#         <Axes: title={'center': 'weather_delay'}>,
#         <Axes: title={'center': 'nas_delay'}>,
#         <Axes: title={'center': 'security_delay'}>],
#        [<Axes: title={'center': 'late_aircraft_delay'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)
